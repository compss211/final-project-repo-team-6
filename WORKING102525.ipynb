# %%
#import libraries
import pandas as pd
import re
import requests
import time
from io import StringIO
import os
import json

# %%
# get rid of parentheses 
# white space before

# %%
#config 
API_KEY = "tSUXiFeF9OmTfzi3x24XsaKvGavaNFUMzQHUaABw"
PROGRESS_FILE = "/Users/sanyakhan/Downloads/parsing_progress_tester1009.json"
OUTPUT_FILE = "/Users/sanyakhan/Downloads/congressional_speeches_parsed_tester1009.csv"
file_path = '/Users/sanyakhan/Downloads/newtest - Sheet1.csv'
df = pd.read_csv(file_path, skiprows=3)
df
# Out:
#                                                 Title  \
# 0   REINTRODUCING THE SERVICES FOR ENDING LONG-TER...
# 1   HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 2   HOMELESS ASSISTANCE ACT OF 2019; Congressional...
# 3   HOMELESS ASSISTANCE ACT OF 2019; Congressional...
# 4   TRIBAL ACCESS TO HOMELESS ASSISTANCE ACT; Cong...
# 5   LEGAL SERVICES FOR HOMELESS VETERANS ACT; Cong...
# 6   HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 7   HOUSING UNHOUSED DISABLED VETERANS ACT; Congre...
# 8   HOMELESS ASSISTANCE ACT OF 2019; Congressional...
# 9   McKINNEY-VENTO HOMELESS ASSISTANCE ACT; Congre...
# 10  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 11  HOMELESS VETERANS ASSISTANCE ACT OF 2004; Cong...
# 12  HOMELESS VETERANS WITH CHILDREN REINTEGRATION ...
#
#                                                   URL  Issue Date  Section  \
# 0   https://www.congress.gov/congressional-record/...  06/13/2019      NaN
# 1   https://www.congress.gov/congressional-record/...  10/15/2019      NaN
# 2   https://www.congress.gov/congressional-record/...  01/13/2020      NaN
# 3   https://www.congress.gov/congressional-record/...  01/14/2020      NaN
# 4   https://www.congress.gov/congressional-record/...  11/18/2019      NaN
# 5   https://www.congress.gov/congressional-record/...  02/25/2020      NaN
# 6   https://www.congress.gov/congressional-record/...  10/15/2019      NaN
# 7   https://www.congress.gov/congressional-record/...  02/10/2025      NaN
# 8   https://www.congress.gov/congressional-record/...  01/13/2020      NaN
# 9   https://www.congress.gov/congressional-record/...  07/20/2017      NaN
# 10  https://www.congress.gov/congressional-record/...  10/15/2019      NaN
# 11  https://www.congress.gov/congressional-record/...  10/06/2004      NaN
# 12  https://www.congress.gov/congressional-record/...  05/17/2021      NaN
#
#     Volume  Number   Page
# 0      165      99   E770
# 1      165     162  H8135
# 2      166       7   H186
# 3      166       8    E37
# 4      165     184  H8926
# 5      166      37  H1176
# 6      165     162  H8138
# 7      171      27   H603
# 8      166       7   H186
# 9      163     123  S4108
# 10     165     162  H8135
# 11     150     125  H8382
# 12     167      85  H2364

# %%
# just loading
file_path = file_path = '/Users/sanyakhan/Downloads/search_results_2025-10-14_0302am.csv'
df = pd.read_csv(file_path, skiprows=2)

# so check if the progress file exists
def load_progress():
    if os.path.exists(PROGRESS_FILE):
        try:
            with open(PROGRESS_FILE, 'r') as f:
                progress = json.load(f)
            print(f"Loaded progress: {progress['processed_rows']} rows already processed")
            return progress
        except:
            print("Could not load progress file, starting fresh")
    return {'processed_rows': 0, 'processed_urls': set()}

def save_progress(processed_rows, processed_urls):
    progress = {
        'processed_rows': processed_rows,
        'processed_urls': list(processed_urls)
    }
    with open(PROGRESS_FILE, 'w') as f:
        json.dump(progress, f)



def append_to_csv(speeches, file_path):
   #if speeches list empty then return
    if not speeches:
        return
    
    #convert the dicionary to dataframe
    speeches_df = pd.DataFrame(speeches)
    if 'Party' not in speeches_df.columns:
        speeches_df['Party'] = pd.NA
    if 'State' not in speeches_df.columns:
        speeches_df['State'] = pd.NA
    # reorder columns
    column_order = [ 'Chamber', 'Session', 'Year', 'Date', 'Speaker', 'Party', 'State' , 'Bill Reference', 'Title', 'URL', 'Volume', 'Number', 'Section', 'turn_number', 'speaker_title', 'speech_text', 'speech_length_words', 'granule_id', 'package_id' ]
    # give the dataframe the columns
    speeches_df = speeches_df[[col for col in column_order if col in speeches_df.columns]]
    
    # append or create file to put speeches in
    if os.path.exists(file_path):
        speeches_df.to_csv(file_path, mode='a', header=False, index=False)
    else:
        speeches_df.to_csv(file_path, mode='w', header=True, index=False)

# uses the url to get where the speech is from (chamber)
def get_chamber(url):
    if pd.isna(url) or not isinstance(url, str):
        return None
    url = url.lower()
    if "senate-section" in url:
        return "Senate"
    elif "house-section" in url:
        return "House"
    elif "extensions-of-remarks" in url:
        return "Extensions"
    return None

# looking in title column of the csv
def get_bill_reference(title):
    if pd.isna(title) or not isinstance(title, str):
        return None
    pattern = r'\b(H\.R\.|S\.|H\.Res\.|S\.Res\.|H\.J\.Res\.|S\.J\.Res\.)\s*\d+\b'
    matches = [m.group(0) for m in re.finditer(pattern, title)]
    return ', '.join(sorted(set(matches))) if matches else None

# parses the date into something govinfo can use
def construct_crec_package_id(date_str):
    if pd.isna(date_str):
        return None
    try:
        date_obj = pd.to_datetime(date_str)
        return f"CREC-{date_obj.strftime('%Y-%m-%d')}"
    except:
        return None

# building URL
#this is essneitally making sure the url is valid
def get_package_granules(package_id, api_key):
    url = f"https://api.govinfo.gov/packages/{package_id}/granules"
    params = {'api_key': api_key, 'offsetMark': '*', 'pageSize': 1000}
    
    try:
        response = requests.get(url, params=params, timeout=10)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.HTTPError as e:
        if e.response.status_code == 404:
            print(f"Package not found (404)")
        else:
            print(f"HTTP Error {e.response.status_code}")
        return None
    except Exception as e:
        print(f"Error getting granules: {e}")
        return None

# get meta data 
def get_granule_content(package_id, granule_id, api_key):
    url = f"https://api.govinfo.gov/packages/{package_id}/granules/{granule_id}/summary"
    params = {'api_key': api_key}
    
    try:
        response = requests.get(url, params=params, timeout=10)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"Error getting granule details: {e}")
        return None
    
# gets raw speech data
def get_granule_text(package_id, granule_id, api_key):
    url = f"https://api.govinfo.gov/packages/{package_id}/granules/{granule_id}/htm"
    params = {'api_key': api_key}
    
    try:
        response = requests.get(url, params=params, timeout=15)
        response.raise_for_status()
        return response.text
    except Exception as e:
        print(f" Error downloading text: {e}")
        return None


#now once we have the speech, we have all the text, we need to parse it by speaker
def parse_speeches_from_text(text):
    if not text:
        return []
    speeches = []
    #regex pattern to identify speaker introduction

    speaker_pattern = r'\n\s*((?:Mr\.|Ms\.|Mrs\.|Senator|The)\s+[A-Z][A-Z\s]+?)(?:\s+of\s+[A-Z][a-z]+)?\.\s'
    
    # Find all speaker introductions
    matches = list(re.finditer(speaker_pattern, text, re.MULTILINE))
    if not matches:
        return []
    
    # Extract speeches between speaker introductions
    for i, match in enumerate(matches):
        speaker_raw = match.group(1).strip()
        start_pos = match.end()
        

        # end position is either the next speaker or end of text
        end_pos = matches[i + 1].start() if i + 1 < len(matches) else len(text)
        
        speech_text = text[start_pos:end_pos].strip()
        
        # dealing w/ whitesapce
        speech_text = re.sub(r'\s+', ' ', speech_text) 
        
        # get speaker info
        title_match = re.match(r'(Mr\.|Ms\.|Mrs\.|Senator|The)\s+(.+)', speaker_raw)
        if title_match:
            title = title_match.group(1)
            name = title_match.group(2).strip()
        else:
            title = None
            name = speaker_raw
        
        # hmmm interesting idk if this is needed
        if len(speech_text) < 20:
            continue
        
        #adding to speech list 
        speeches.append({
            'speaker_title': title,
            'speaker_name': name.title(),  # Convert from ALL CAPS
            'speech_text': speech_text,
            'speech_length_words': len(speech_text.split()),
            'turn_number': len(speeches) + 1
        })
    
    return speeches


# ok now we are actually pulling from the url
def process_congressional_record(row, api_key):
    url = row.get("URL")
    date = row.get("Date")
    title = row.get("Title")
    
    if pd.isna(url) or pd.isna(date):
        return []
    
    print(f"🔍 Processing: {url}")
    
    # Construct package ID
    package_id = construct_crec_package_id(date)
    if not package_id:
        print("Could not construct package ID")
        return []
    
    print(f" Package ID: {package_id}")
    
    # Get granules
    granules_data = get_package_granules(package_id, api_key)
    if not granules_data or 'granules' not in granules_data:
        print("No granules found")
        return []
    
    granules = granules_data.get('granules', [])
    print(f"Found {len(granules)} granules")
    
    # Extract section from URL
    section_match = re.search(r'article/([A-Z])(\d+)(?:-\d+)?', url)
    if not section_match:
        print("Could not extract section")
        return []
    
    section_letter = section_match.group(1)
    section_number = section_match.group(2)
    section_pattern = f"Pg{section_letter}{section_number}"
    
    print(f"Looking for pattern: {section_pattern}")
    
    # Find matching granule
    matching_granule = None
    for granule in granules:
        granule_id = granule.get('granuleId', '')
        if section_pattern in granule_id:
            matching_granule = granule
            print(f"Found matching granule: {granule_id}")
            break
    
    if not matching_granule:
        print(f"No matching granule found")
        return []
    
    granule_id = matching_granule['granuleId']
    
    # Get granule metadata
    granule_detail = get_granule_content(package_id, granule_id, api_key)

    # Get full text
    print(f"Downloading text...")
    text = get_granule_text(package_id, granule_id, api_key)
    
    if not text:
        print(f"Could not download text")
        return []
    
    # Parse speeches
    print(f"Parsing speeches...")
    speeches = parse_speeches_from_text(text)
    
    if not speeches:
        print(f"No speeches found in text")
        return []
    
    print(f"Found {len(speeches)} speeches")
    
    # Add metadata to each speech
    speech_records = []
    for speech in speeches:
        record = {
            'Chamber': get_chamber(url),
            'Session': row.get('Volume'),
            'Year': row.get('Year'),
            'Date': date,
            'Speaker': speech['speaker_name'],
            'Bill Reference': get_bill_reference(title),
            'Title': title,
            'URL': url,
            'Volume': row.get('Volume'),
            'Number': row.get('Number'),
            'Section': row.get('Section'),
            'speaker_title': speech['speaker_title'],
            'speech_text': speech['speech_text'],
            'speech_length_words': speech['speech_length_words'],
            'turn_number': speech['turn_number'],
            'granule_id': granule_id,
            'package_id': package_id
        }
        speech_records.append(record)
    
    return speech_records

# Parse dates
issue_date = pd.to_datetime(df["Issue Date"], errors="coerce")
df["Date"] = issue_date.dt.date
df["Year"] = issue_date.dt.year

# Process records
print("\n" + "=" * 60)
print("STARTING CONGRESSIONAL RECORD SPEECH PARSING")
print("=" * 60 + "\n")

# Load previous progress
progress = load_progress()
processed_urls = set(progress.get('processed_urls', []))
start_row = progress.get('processed_rows', 0)

# Limit processing for testing
MAX_ROWS_TO_PROCESS = None  # Set to None to process ALL rows
rows_to_process = df.head(MAX_ROWS_TO_PROCESS) if MAX_ROWS_TO_PROCESS else df

# Skip already processed rows
if start_row > 0:
    rows_to_process = rows_to_process.iloc[start_row:]
    print(f" Resuming from row {start_row + 1}")

total_speeches_saved = 0
success_count = 0
failure_count = 0
batch_speeches = []  # Collect speeches for batch saving
SAVE_EVERY = 10  # Save progress every N rows

print(f"Total rows to process: {len(rows_to_process)}")
print(f"Progress will be saved every {SAVE_EVERY} rows\n")

for i, (idx, row) in enumerate(rows_to_process.iterrows(), 1):
    actual_row_num = start_row + i
    print(f"\n[{actual_row_num}/{len(df)}]", end=" ")
    
    url = row.get('URL')
    
    # Skip if already processed, json
    if url in processed_urls:
        print(f" Skipping (already processed)")
        continue
    
    # deal w /rate limiting
    time.sleep(0.5)
    
    # Process record
    speeches = process_congressional_record(row, API_KEY)
    
    if speeches:
        batch_speeches.extend(speeches)
        success_count += 1
        total_speeches_saved += len(speeches)
    else:
        failure_count += 1
    
    #mark as processed
    processed_urls.add(url)
    
    # save progress periodically
    if i % SAVE_EVERY == 0:
        print(f"\n Saving progress...")
        append_to_csv(batch_speeches, OUTPUT_FILE)
        save_progress(actual_row_num, processed_urls)
        batch_speeches = []  # Clear batch
        
        print(f"📊 Progress Update:")
        print(f"   Processed: {actual_row_num}/{len(df)} rows")
        print(f"   Successes: {success_count} | Failures: {failure_count}")
        print(f"   Total speeches saved: {total_speeches_saved}")
        
#save any remaining speeches
if batch_speeches:
    print(f"\n Saving final batch...")
    append_to_csv(batch_speeches, OUTPUT_FILE)
    total_speeches_saved += len(batch_speeches)

# Save final progress
save_progress(len(df), processed_urls)

# idg what thsi si 
print("\n" + "=" * 60)
print("PROCESSING COMPLETE")
print("=" * 60)

if os.path.exists(OUTPUT_FILE):
    # Load final results
    final_df = pd.read_csv(OUTPUT_FILE)
    
    
    # Show sample
    print("\n" + "=" * 60)
    print("SAMPLE DATA (first 3 speeches)")
    print("=" * 60)
    for idx, speech in final_df.head(3).iterrows():
        print(f"\nSpeech {idx + 1}:")
        print(f"  Title: {speech['Title'][:60]}...")
        print(f"  Turn: {speech['turn_number']}")
        print(f"  Words: {speech['speech_length_words']}")
        print(f"  Text preview: {speech['speech_text'][:150]}...")
    
    print(f"\n Final dataset saved to '{OUTPUT_FILE}'")
    
else:
    print("No speeches were successfully parsed")
    print("Check the error messages above for details")

print("\n" + "=" * 60)
# Out:
# ============================================================
# STARTING CONGRESSIONAL RECORD SPEECH PARSING
# ============================================================
#
# Loaded progress: 7 rows already processed
#  Resuming from row 8
# Total rows to process: 0
# Progress will be saved every 10 rows
#
#
# ============================================================
# PROCESSING COMPLETE
# ============================================================
#
# ============================================================
# SAMPLE DATA (first 3 speeches)
# ============================================================
#
# Speech 1:
#   Title: REINTRODUCING THE SERVICES FOR ENDING LONG-TERM HOMELESSNESS...
#   Turn: 1
#   Words: 329
#   Text preview: Madam Speaker, I rise today to congratulate Norwich Superintendent of Public Schools, Abby Dolliver, on a career in education spanning 33 years, inclu...
#
# Speech 2:
#   Title: HOMELESS VETERAN FAMILIES ACT; Congressional Record Vol. 165...
#   Turn: 1
#   Words: 234
#   Text preview: Mr. Speaker, I move to suspend the rules and pass the bill (H.R. 95) to amend title 38, United States Code, to ensure that children of homeless vetera...
#
# Speech 3:
#   Title: HOMELESS VETERAN FAMILIES ACT; Congressional Record Vol. 165...
#   Turn: 2
#   Words: 49
#   Text preview: Mr. Speaker, I ask unanimous consent that all Members may have 5 legislative days in which to revise and extend their remarks and to insert extraneous...
#
#  Final dataset saved to '/Users/sanyakhan/Downloads/congressional_speeches_parsed_tester1009.csv'
#
# ============================================================

# %%
out_df = pd.read_csv(OUTPUT_FILE, dtype=str)
out_df.head(5)
# Out:
#       Chamber Session  Year        Date   Speaker Party State Bill Reference  \
# 0  Extensions     165  2019  2019-06-13  Courtney   NaN   NaN            NaN
# 1       House     165  2019  2019-10-15    Takano   NaN   NaN            NaN
# 2       House     165  2019  2019-10-15    Takano   NaN   NaN            NaN
# 3       House     165  2019  2019-10-15    Takano   NaN   NaN            NaN
# 4       House     165  2019  2019-10-15   David P   NaN   NaN            NaN
#
#                                                Title  \
# 0  REINTRODUCING THE SERVICES FOR ENDING LONG-TER...
# 1  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 2  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 3  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 4  HOMELESS VETERAN FAMILIES ACT; Congressional R...
#
#                                                  URL Volume Number Section  \
# 0  https://www.congress.gov/congressional-record/...    165     99     NaN
# 1  https://www.congress.gov/congressional-record/...    165    162     NaN
# 2  https://www.congress.gov/congressional-record/...    165    162     NaN
# 3  https://www.congress.gov/congressional-record/...    165    162     NaN
# 4  https://www.congress.gov/congressional-record/...    165    162     NaN
#
#   turn_number speaker_title  \
# 0           1           Mr.
# 1           1           Mr.
# 2           2           Mr.
# 3           3           Mr.
# 4           4           Mr.
#
#                                          speech_text speech_length_words  \
# 0  Madam Speaker, I rise today to congratulate No...                 329
# 1  Mr. Speaker, I move to suspend the rules and p...                 234
# 2  Mr. Speaker, I ask unanimous consent that all ...                  49
# 3  Mr. Speaker, I yield myself such time as I may...                 500
# 4  ROE of Tennessee. Mr. Speaker, I yield myself ...                 321
#
#                     granule_id       package_id
# 0   CREC-2019-06-13-pt1-PgE770  CREC-2019-06-13
# 1  CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 2  CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 3  CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 4  CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15

# %%
def norm_speech(x):
    if not isinstance(x, str): return None
    s = x
    if "house" in s.lower():  return "HOUSE"
    if "senate" in s.lower(): return "SENATE"
    return None

def norm_member(x):
    if not isinstance(x, str): return None
    s = x.strip().lower()
    if s in {"rep"}: return "HOUSE"
    if s in {"sen"}: return "SENATE"
    return None

def last_name(name):
    if not isinstance(name, str) or not name.strip():
        return []
    s = name.upper().strip()
    s = re.sub(r"[^\w\s'\-]", " ", s)
    s = re.sub(r"\s+", " ", s)
    parts = s.split(" ")
    full_last = " ".join(parts)
    return [full_last]

mem_df = pd.read_csv(members_fp, dtype=str)
mem_df.columns = [c.lower() for c in mem_df.columns]

mem_df["last_name_norm"] = mem_df["last_name"].fillna("").str.upper().str.strip()
mem_df["start_dt"] = pd.to_datetime(mem_df.get("term_start"), errors="coerce")
mem_df["end_dt"] = pd.to_datetime(mem_df.get("term_end"), errors="coerce").fillna(pd.Timestamp("2100-01-01"))

if "term_type" in mem_df.columns:
    mem_df["member_type"] = mem_df["term_type"].map(norm_member)
else:
    mem_df["member_type"] = pd.NA

by_full_last = {}
for i, r in mem_df.iterrows():
    key = r.get("last_name_norm", "")
    if isinstance(key, str) and key.strip():
        by_full_last.setdefault(key, []).append(i)

def pick_candidate(speaker, speech_date, speech_type):
    if not isinstance(speaker, str) or not speaker.strip():
        return None, None
    opts = last_name(speaker)
    full_last = opts[0] if opts else None
    if not full_last:
        return None, None
    cand_idx = set(by_full_last.get(full_last, []))
    if not cand_idx:
        return None, None
    cands = mem_df.loc[list(cand_idx)].copy()
    if isinstance(speech_type, str):
        strict = cands[(cands["member_type"].isna()) | (cands["member_type"] == speech_type)]
        if strict.empty:
            return None, None
    else:
        strict = cands
    if len(strict) == 1:
        r = strict.iloc[0]
        return str(r["party"]).strip(), str(r["state"]).strip()
    ps = strict[["party","state"]].dropna()
    if not ps.empty and len(ps.drop_duplicates()) == 1:
        r = ps.iloc[0]
        return str(r["party"]).strip(), str(r["state"]).strip()
    return None, None

out_df["speech_type"]= out_df["Chamber"].map(norm_speech) if "Chamber" in out_df.columns else None
out_df["Date"] = pd.to_datetime(out_df["Date"], errors="coerce")
mask_to_fix = out_df["Party"].isna() | out_df["State"].isna()
filled_party = filled_state = 0

for i in out_df.index[mask_to_fix]:
    party0, state0 = out_df.at[i,"Party"], out_df.at[i,"State"]
    party, state = pick_candidate(out_df.at[i,"Speaker"], out_df.at[i,"Date"], out_df.at[i,"speech_type"])
    if pd.isna(party0) and party:
        out_df.at[i,"Party"] = party
        filled_party += 1
    if pd.isna(state0) and state:
        out_df.at[i,"State"] = state
        filled_state += 1

out_df.drop(columns=["speech_type"], errors="ignore", inplace=True)
print(f"Filled Party: {filled_party} | Filled State: {filled_state}")
# Out:
# Filled Party: 24 | Filled State: 24

# %%
out_df.head()

# %%
members_fp = "/Users/sanyakhan/Downloads/Legislators - legislators-historical (1).csv"
members_df = pd.read_csv(members_fp, dtype=str)
members_df.tail(5)
members_df.columns
# Out:
# Index(['bioguide', 'thomas', 'lis', 'govtrack', 'opensecrets', 'votesmart',
#        'fec', 'cspan', 'wikipedia', 'house_history', 'ballotpedia', 'maplight',
#        'icpsr', 'wikidata', 'google_entity_id', 'pictorial', 'first_name',
#        'middle_name', 'last_name', 'nickname', 'suffix', 'official_full_name',
#        'birthday', 'gender', 'term_type', 'term_start', 'term_end', 'state',
#        'district', 'senate_class', 'party', 'caucus', 'state_rank', 'url',
#        'address', 'phone', 'fax', 'contact_form', 'office', 'rss_url',
#        'how_appointed'],
#       dtype='object')

# %%
for each in index:
    curr_name = out_df['Speaker'][each]
    date = out_df['Date'][each]
    print('Current Name: ', curr_name)
    print('Speech Date: ', date)
    print('-----')
    temp_list = []
    #for courtney current go through whole DS
    for i in members_df.index:
        #Have i accounted for edge cases?
        if members_df['last_name'][i] == curr_name:
            if pd.to_datetime(members_df['term_start'][i]) <= pd.to_datetime(date) <= pd.to_datetime(members_df['term_end'][i]):
                 print(members_df['first_name'][i] + ' ' + members_df['last_name'][i])
                 temp_list.extend([i]) 
    print(temp_list)
    if len(temp_list) == 1:
        out_df['State'][each] = members_df['state'][temp_list[0]]
        out_df['Party'][each] = members_df['party'][temp_list[0]]
# Out:
# Current Name:  Courtney
# Speech Date:  2019-06-13 00:00:00
# -----
# Joe Courtney
# [43037]
# Current Name:  David P
# Speech Date:  2019-10-15 00:00:00
# -----
# []
# Current Name:  David P
# Speech Date:  2019-10-15 00:00:00
# -----
# []
# Current Name:  David P
# Speech Date:  2019-10-15 00:00:00
# -----
# []
# Current Name:  Hill
# Speech Date:  2020-01-13 00:00:00
# -----
# J. Hill
# [44454]
# Current Name:  Johnson
# Speech Date:  2020-01-13 00:00:00
# -----
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:17: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   out_df['State'][each] = members_df['state'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_df['State'][each] = members_df['state'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   out_df['Party'][each] = members_df['party'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_df['Party'][each] = members_df['party'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:17: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   out_df['State'][each] = members_df['state'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_df['State'][each] = members_df['state'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   out_df['Party'][each] = members_df['party'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_df['Party'][each] = members_df['party'][temp_list[0]]
# Eddie Johnson
# Bill Johnson
# Henry Johnson
# Ron Johnson
# Mike Johnson
# Dusty Johnson
# [41876, 42243, 43308, 43313, 44726, 44995]
# Current Name:  Scott
# Speech Date:  2020-01-14 00:00:00
# -----
# Austin Scott
# David Scott
# Robert Scott
# Tim Scott
# Rick Scott
# [43816, 43828, 43845, 43852, 45047]
# Current Name:  Green
# Speech Date:  2019-11-18 00:00:00
# -----
# Mark Green
# Al Green
# [42690, 43219]
# Current Name:  Green
# Speech Date:  2019-11-18 00:00:00
# -----
# Mark Green
# Al Green
# [42690, 43219]
# Current Name:  Green
# Speech Date:  2019-11-18 00:00:00
# -----
# Mark Green
# Al Green
# [42690, 43219]
# Current Name:  Wagner
# Speech Date:  2019-11-18 00:00:00
# -----
# Ann Wagner
# [44304]
# Current Name:  Green
# Speech Date:  2019-11-18 00:00:00
# -----
# Mark Green
# Al Green
# [42690, 43219]
# Current Name:  Heck
# Speech Date:  2019-11-18 00:00:00
# -----
# Denny Heck
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:17: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   out_df['State'][each] = members_df['state'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_df['State'][each] = members_df['state'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   out_df['Party'][each] = members_df['party'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_df['Party'][each] = members_df['party'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:17: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   out_df['State'][each] = members_df['state'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_df['State'][each] = members_df['state'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   out_df['Party'][each] = members_df['party'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_df['Party'][each] = members_df['party'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:17: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   out_df['State'][each] = members_df['state'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_df['State'][each] = members_df['state'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   out_df['Party'][each] = members_df['party'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_df['Party'][each] = members_df['party'][temp_list[0]]
# [41567]
# Current Name:  Wagner
# Speech Date:  2019-11-18 00:00:00
# -----
# Ann Wagner
# [44304]
# Current Name:  Green
# Speech Date:  2019-11-18 00:00:00
# -----
# Mark Green
# Al Green
# [42690, 43219]
# Current Name:  Wagner
# Speech Date:  2019-11-18 00:00:00
# -----
# Ann Wagner
# [44304]
# Current Name:  Green
# Speech Date:  2019-11-18 00:00:00
# -----
# Mark Green
# Al Green
# [42690, 43219]
# Current Name:  David P
# Speech Date:  2020-02-25 00:00:00
# -----
# []
# Current Name:  David P
# Speech Date:  2020-02-25 00:00:00
# -----
# []
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:17: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   out_df['State'][each] = members_df['state'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_df['State'][each] = members_df['state'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   out_df['Party'][each] = members_df['party'][temp_list[0]]
# /var/folders/m_/y8pl7q8n0kgg5_f27n0x6vpm0000gn/T/ipykernel_89476/965205127.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_df['Party'][each] = members_df['party'][temp_list[0]]

# %%
out_df
# Out:
#        Chamber Session  Year       Date      Speaker       Party State  \
# 0   Extensions     165  2019 2019-06-13     Courtney    Democrat    CT
# 1        House     165  2019 2019-10-15       Takano    Democrat    CA
# 2        House     165  2019 2019-10-15       Takano    Democrat    CA
# 3        House     165  2019 2019-10-15       Takano    Democrat    CA
# 4        House     165  2019 2019-10-15      David P         NaN   NaN
# 5        House     165  2019 2019-10-15       Takano    Democrat    CA
# 6        House     165  2019 2019-10-15     Brownley    Democrat    CA
# 7        House     165  2019 2019-10-15       Takano    Democrat    CA
# 8        House     165  2019 2019-10-15     Brownley    Democrat    CA
# 9        House     165  2019 2019-10-15      David P         NaN   NaN
# 10       House     165  2019 2019-10-15      David P         NaN   NaN
# 11       House     165  2019 2019-10-15       Takano    Democrat    CA
# 12       House     165  2019 2019-10-15  Jackson Lee    Democrat    TX
# 13       House     165  2019 2019-10-15       Takano    Democrat    CA
# 14       House     166  2020 2020-01-13  San Nicolas    Democrat    GU
# 15       House     166  2020 2020-01-13  San Nicolas    Democrat    GU
# 16       House     166  2020 2020-01-13  San Nicolas    Democrat    GU
# 17       House     166  2020 2020-01-13         Hill  Republican    AR
# 18       House     166  2020 2020-01-13  San Nicolas    Democrat    GU
# 19       House     166  2020 2020-01-13      Johnson         NaN   NaN
# 20  Extensions     166  2020 2020-01-14        Scott         NaN   NaN
# 21       House     165  2019 2019-11-18        Green         NaN   NaN
# 22       House     165  2019 2019-11-18        Green         NaN   NaN
# 23       House     165  2019 2019-11-18        Green         NaN   NaN
# 24       House     165  2019 2019-11-18       Wagner  Republican    MO
# 25       House     165  2019 2019-11-18        Green         NaN   NaN
# 26       House     165  2019 2019-11-18         Heck    Democrat    WA
# 27       House     165  2019 2019-11-18       Wagner  Republican    MO
# 28       House     165  2019 2019-11-18        Green         NaN   NaN
# 29       House     165  2019 2019-11-18       Wagner  Republican    MO
# 30       House     165  2019 2019-11-18        Green         NaN   NaN
# 31       House     166  2020 2020-02-25       Takano    Democrat    CA
# 32       House     166  2020 2020-02-25       Takano    Democrat    CA
# 33       House     166  2020 2020-02-25       Takano    Democrat    CA
# 34       House     166  2020 2020-02-25      David P         NaN   NaN
# 35       House     166  2020 2020-02-25       Takano    Democrat    CA
# 36       House     166  2020 2020-02-25      Panetta    Democrat    CA
# 37       House     166  2020 2020-02-25      David P         NaN   NaN
# 38       House     166  2020 2020-02-25       Takano    Democrat    CA
# 39       House     165  2019 2019-10-15      Scalise  Republican    LA
# 40       House     165  2019 2019-10-15      Scalise  Republican    LA
# 41       House     165  2019 2019-10-15      Scalise  Republican    LA
# 42       House     165  2019 2019-10-15      Scalise  Republican    LA
#
#    Bill Reference                                              Title  \
# 0             NaN  REINTRODUCING THE SERVICES FOR ENDING LONG-TER...
# 1             NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 2             NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 3             NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 4             NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 5             NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 6             NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 7             NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 8             NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 9             NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 10            NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 11            NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 12            NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 13            NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 14            NaN  HOMELESS ASSISTANCE ACT OF 2019; Congressional...
# 15            NaN  HOMELESS ASSISTANCE ACT OF 2019; Congressional...
# 16            NaN  HOMELESS ASSISTANCE ACT OF 2019; Congressional...
# 17            NaN  HOMELESS ASSISTANCE ACT OF 2019; Congressional...
# 18            NaN  HOMELESS ASSISTANCE ACT OF 2019; Congressional...
# 19            NaN  HOMELESS ASSISTANCE ACT OF 2019; Congressional...
# 20            NaN  HOMELESS ASSISTANCE ACT OF 2019; Congressional...
# 21            NaN  TRIBAL ACCESS TO HOMELESS ASSISTANCE ACT; Cong...
# 22            NaN  TRIBAL ACCESS TO HOMELESS ASSISTANCE ACT; Cong...
# 23            NaN  TRIBAL ACCESS TO HOMELESS ASSISTANCE ACT; Cong...
# 24            NaN  TRIBAL ACCESS TO HOMELESS ASSISTANCE ACT; Cong...
# 25            NaN  TRIBAL ACCESS TO HOMELESS ASSISTANCE ACT; Cong...
# 26            NaN  TRIBAL ACCESS TO HOMELESS ASSISTANCE ACT; Cong...
# 27            NaN  TRIBAL ACCESS TO HOMELESS ASSISTANCE ACT; Cong...
# 28            NaN  TRIBAL ACCESS TO HOMELESS ASSISTANCE ACT; Cong...
# 29            NaN  TRIBAL ACCESS TO HOMELESS ASSISTANCE ACT; Cong...
# 30            NaN  TRIBAL ACCESS TO HOMELESS ASSISTANCE ACT; Cong...
# 31            NaN  LEGAL SERVICES FOR HOMELESS VETERANS ACT; Cong...
# 32            NaN  LEGAL SERVICES FOR HOMELESS VETERANS ACT; Cong...
# 33            NaN  LEGAL SERVICES FOR HOMELESS VETERANS ACT; Cong...
# 34            NaN  LEGAL SERVICES FOR HOMELESS VETERANS ACT; Cong...
# 35            NaN  LEGAL SERVICES FOR HOMELESS VETERANS ACT; Cong...
# 36            NaN  LEGAL SERVICES FOR HOMELESS VETERANS ACT; Cong...
# 37            NaN  LEGAL SERVICES FOR HOMELESS VETERANS ACT; Cong...
# 38            NaN  LEGAL SERVICES FOR HOMELESS VETERANS ACT; Cong...
# 39            NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 40            NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 41            NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
# 42            NaN  HOMELESS VETERAN FAMILIES ACT; Congressional R...
#
#                                                   URL Volume Number Section  \
# 0   https://www.congress.gov/congressional-record/...    165     99     NaN
# 1   https://www.congress.gov/congressional-record/...    165    162     NaN
# 2   https://www.congress.gov/congressional-record/...    165    162     NaN
# 3   https://www.congress.gov/congressional-record/...    165    162     NaN
# 4   https://www.congress.gov/congressional-record/...    165    162     NaN
# 5   https://www.congress.gov/congressional-record/...    165    162     NaN
# 6   https://www.congress.gov/congressional-record/...    165    162     NaN
# 7   https://www.congress.gov/congressional-record/...    165    162     NaN
# 8   https://www.congress.gov/congressional-record/...    165    162     NaN
# 9   https://www.congress.gov/congressional-record/...    165    162     NaN
# 10  https://www.congress.gov/congressional-record/...    165    162     NaN
# 11  https://www.congress.gov/congressional-record/...    165    162     NaN
# 12  https://www.congress.gov/congressional-record/...    165    162     NaN
# 13  https://www.congress.gov/congressional-record/...    165    162     NaN
# 14  https://www.congress.gov/congressional-record/...    166      7     NaN
# 15  https://www.congress.gov/congressional-record/...    166      7     NaN
# 16  https://www.congress.gov/congressional-record/...    166      7     NaN
# 17  https://www.congress.gov/congressional-record/...    166      7     NaN
# 18  https://www.congress.gov/congressional-record/...    166      7     NaN
# 19  https://www.congress.gov/congressional-record/...    166      7     NaN
# 20  https://www.congress.gov/congressional-record/...    166      8     NaN
# 21  https://www.congress.gov/congressional-record/...    165    184     NaN
# 22  https://www.congress.gov/congressional-record/...    165    184     NaN
# 23  https://www.congress.gov/congressional-record/...    165    184     NaN
# 24  https://www.congress.gov/congressional-record/...    165    184     NaN
# 25  https://www.congress.gov/congressional-record/...    165    184     NaN
# 26  https://www.congress.gov/congressional-record/...    165    184     NaN
# 27  https://www.congress.gov/congressional-record/...    165    184     NaN
# 28  https://www.congress.gov/congressional-record/...    165    184     NaN
# 29  https://www.congress.gov/congressional-record/...    165    184     NaN
# 30  https://www.congress.gov/congressional-record/...    165    184     NaN
# 31  https://www.congress.gov/congressional-record/...    166     37     NaN
# 32  https://www.congress.gov/congressional-record/...    166     37     NaN
# 33  https://www.congress.gov/congressional-record/...    166     37     NaN
# 34  https://www.congress.gov/congressional-record/...    166     37     NaN
# 35  https://www.congress.gov/congressional-record/...    166     37     NaN
# 36  https://www.congress.gov/congressional-record/...    166     37     NaN
# 37  https://www.congress.gov/congressional-record/...    166     37     NaN
# 38  https://www.congress.gov/congressional-record/...    166     37     NaN
# 39  https://www.congress.gov/congressional-record/...    165    162     NaN
# 40  https://www.congress.gov/congressional-record/...    165    162     NaN
# 41  https://www.congress.gov/congressional-record/...    165    162     NaN
# 42  https://www.congress.gov/congressional-record/...    165    162     NaN
#
#    turn_number speaker_title  \
# 0            1           Mr.
# 1            1           Mr.
# 2            2           Mr.
# 3            3           Mr.
# 4            4           Mr.
# 5            5           Mr.
# 6            6           Ms.
# 7            7           Mr.
# 8            8           Ms.
# 9            9           Mr.
# 10          10           Mr.
# 11          11           Mr.
# 12          12           Ms.
# 13          13           Mr.
# 14           1           Mr.
# 15           2           Mr.
# 16           3           Mr.
# 17           4           Mr.
# 18           5           Mr.
# 19           6           Ms.
# 20           1           Mr.
# 21           1           Mr.
# 22           2           Mr.
# 23           3           Mr.
# 24           4          Mrs.
# 25           5           Mr.
# 26           6           Mr.
# 27           7          Mrs.
# 28           8           Mr.
# 29           9          Mrs.
# 30          10           Mr.
# 31           1           Mr.
# 32           2           Mr.
# 33           3           Mr.
# 34           4           Mr.
# 35           5           Mr.
# 36           6           Mr.
# 37           7           Mr.
# 38           8           Mr.
# 39           1           Mr.
# 40           2           Mr.
# 41           3           Mr.
# 42           4           Mr.
#
#                                           speech_text speech_length_words  \
# 0   Madam Speaker, I rise today to congratulate No...                 329
# 1   Mr. Speaker, I move to suspend the rules and p...                 234
# 2   Mr. Speaker, I ask unanimous consent that all ...                  49
# 3   Mr. Speaker, I yield myself such time as I may...                 500
# 4   ROE of Tennessee. Mr. Speaker, I yield myself ...                 321
# 5   Mr. Speaker, I yield 3 minutes to the gentlewo...                  28
# 6   Mr. Speaker, I thank the chairman for yielding...                 435
# 7   I yield the gentlewoman from California an add...                  10
# 8   Mr. Speaker, providing housing to our Nation's...                 116
# 9   ROE of Tennessee. Mr. Speaker, I yield 5 minut...                 564
# 10  ROE of Tennessee. Mr. Speaker, I yield myself ...                 164
# 11  Mr. Speaker, I certainly also want to congratu...                 127
# 12  Mr. Speaker, I rise in strong support of H.R. ...                 356
# 13  Mr. Speaker, on that I demand the yeas and nay...                  38
# 14  Madam Speaker, I move to suspend the rules and...                 402
# 15  Madam Speaker, I ask unanimous consent that al...                  50
# 16  Madam Speaker, I yield myself as much time as ...                 376
# 17  Madam Speaker, I yield myself such time as I m...                 373
# 18  Madam Speaker, I yield myself the balance of m...                  72
# 19  Madam Speaker, today, I rise in support of H.R...                 269
# 20  Madam Speaker, I rise today to share a word ab...                 573
# 21  Mr. Speaker, I move to suspend the rules and p...                 450
# 22  Mr. Speaker, I ask unanimous consent that all ...                  50
# 23  Mr. Speaker, I rise in support of H.R. 4029, t...                 222
# 24  Mr. Speaker, I yield myself such time as I may...                 223
# 25  Mr. Speaker, I yield 5 minutes to the gentlema...                  26
# 26  Mr. Speaker, I rise today in strong support of...                 592
# 27  Mr. Speaker, I yield as much time as he may co...                 173
# 28  Mr. Speaker, I continue to reserve the balance...                  11
# 29  Mr. Speaker, I urge my colleagues once again t...                  31
# 30  Mr. Speaker, I yield myself such time as I may...                 204
# 31  Madam Speaker, I move to suspend the rules and...                1018
# 32  Madam Speaker, I ask unanimous consent that al...                  51
# 33  Madam Speaker, I yield myself such time as I m...                 428
# 34  ROE of Tennessee. Madam Speaker, I yield mysel...                 331
# 35  Madam Speaker, I yield 3 minutes to the gentle...                  26
# 36  Madam Speaker, I thank the chairman and rankin...                 531
# 37  ROE of Tennessee. Madam Speaker, I yield mysel...                 134
# 38  Madam Speaker, I yield myself the balance of m...                 234
# 39  Madam Speaker, I have a parliamentary inquiry....                  18
# 40  Madam Speaker, only three times in the history...                  53
# 41  Madam Speaker, my parliamentary inquiry is thi...                  33
# 42  Madam Speaker, we ought to know the answer to ...                  14
#
#                      granule_id       package_id
# 0    CREC-2019-06-13-pt1-PgE770  CREC-2019-06-13
# 1   CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 2   CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 3   CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 4   CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 5   CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 6   CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 7   CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 8   CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 9   CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 10  CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 11  CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 12  CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 13  CREC-2019-10-15-pt1-PgH8135  CREC-2019-10-15
# 14   CREC-2020-01-13-pt1-PgH186  CREC-2020-01-13
# 15   CREC-2020-01-13-pt1-PgH186  CREC-2020-01-13
# 16   CREC-2020-01-13-pt1-PgH186  CREC-2020-01-13
# 17   CREC-2020-01-13-pt1-PgH186  CREC-2020-01-13
# 18   CREC-2020-01-13-pt1-PgH186  CREC-2020-01-13
# 19   CREC-2020-01-13-pt1-PgH186  CREC-2020-01-13
# 20    CREC-2020-01-14-pt1-PgE37  CREC-2020-01-14
# 21  CREC-2019-11-18-pt1-PgH8926  CREC-2019-11-18
# 22  CREC-2019-11-18-pt1-PgH8926  CREC-2019-11-18
# 23  CREC-2019-11-18-pt1-PgH8926  CREC-2019-11-18
# 24  CREC-2019-11-18-pt1-PgH8926  CREC-2019-11-18
# 25  CREC-2019-11-18-pt1-PgH8926  CREC-2019-11-18
# 26  CREC-2019-11-18-pt1-PgH8926  CREC-2019-11-18
# 27  CREC-2019-11-18-pt1-PgH8926  CREC-2019-11-18
# 28  CREC-2019-11-18-pt1-PgH8926  CREC-2019-11-18
# 29  CREC-2019-11-18-pt1-PgH8926  CREC-2019-11-18
# 30  CREC-2019-11-18-pt1-PgH8926  CREC-2019-11-18
# 31  CREC-2020-02-25-pt1-PgH1176  CREC-2020-02-25
# 32  CREC-2020-02-25-pt1-PgH1176  CREC-2020-02-25
# 33  CREC-2020-02-25-pt1-PgH1176  CREC-2020-02-25
# 34  CREC-2020-02-25-pt1-PgH1176  CREC-2020-02-25
# 35  CREC-2020-02-25-pt1-PgH1176  CREC-2020-02-25
# 36  CREC-2020-02-25-pt1-PgH1176  CREC-2020-02-25
# 37  CREC-2020-02-25-pt1-PgH1176  CREC-2020-02-25
# 38  CREC-2020-02-25-pt1-PgH1176  CREC-2020-02-25
# 39  CREC-2019-10-15-pt1-PgH8138  CREC-2019-10-15
# 40  CREC-2019-10-15-pt1-PgH8138  CREC-2019-10-15
# 41  CREC-2019-10-15-pt1-PgH8138  CREC-2019-10-15
# 42  CREC-2019-10-15-pt1-PgH8138  CREC-2019-10-15
